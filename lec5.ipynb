# %%
import numpy as np
import pandas as pd
from IPython.display import display
pd.read_csv(r'C:\Users\Shani\OneDrive\Documents\school\Ecom\dataScience\dataScience-Lec5-9-MAR-25\example.csv')
df=pd.read_csv('example.csv')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
#Class Exercise=Dataframe functions
tips= pd.read_csv("tips.csv",index_col='Payment ID')
display(tips)
df=tips.copy()
df=df[['Payer Name','tip','total_bill']]
df['total_payment']=df['total_bill']+df['tip']
df['tip_precentage']=(df['tip']/df['total_payment'])*100
# df.insert(1,'total_payment',total_payment)
# df.insert(1,'tip_precentage',(df['tip']/total_payment)*100)
display(df)
df.drop('total_payment',axis=1,inplace=True)
df.drop('tip_precentage',axis=1,inplace=True)
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...
